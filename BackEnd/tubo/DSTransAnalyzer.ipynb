# %%
import pandas as pd
import numpy as np
from pathlib import Path

class BondTransactionAnalyzer:
    def __init__(self, config):
        self.config = {
            "input_files": ["1.csv", "2.csv"],
            "result_folder": "chain_result2",
            "interest_rate_bond_threshold": 0.01,
            "other_bond_threshold": 0.2,
            "profit_threshold": 5000,  # 万元
            "remove_market_makers": False,
            "market_maker_list": "maker.csv",
            "required_columns": {
                "trade_id": "dl_cd",
                "settlement_date": "stlmnt_dt",
                "trade_time": "dl_tm",
                "trade_type": "trdng_md_cd",
                "bond_type": "bond_indctr_list",
                "bond_name": "bnds_nm",
                "seller": "slr_instn_cn_shrt_nm",
                "buyer": "byr_instn_cn_shrt_nm",
                "seller_trader": "slr_trdr_nm",
                "buyer_trader": "byr_trdr_nm",
                "clean_price": "net_prc",
                "yield": "yld_to_mrty",
                "nominal_amount": "nmnl_vol",
                "settlement_amount": "stlmnt_amnt",
                "trade_date": "txn_dt"
            }
        }
        self.config.update(config)
        
        self.all_transactions = None
        self.market_makers = set()
        Path(self.config["result_folder"]).mkdir(exist_ok=True)

    def load_data(self):
        if self.config["remove_market_makers"]:
            maker_df = pd.read_csv(self.config["market_maker_list"], encoding="GBK")
            self.market_makers = set(maker_df["机构名称"].values)
        
        dfs = []
        for f in self.config["input_files"]:
            try:
                df = pd.read_csv(f, encoding='utf-8')
            except UnicodeDecodeError:
                df = pd.read_csv(f, encoding='GB18030')  # 处理中文编码
            dfs.append(df)
        combined_df = pd.concat(dfs, ignore_index=True)
        self.all_transactions = combined_df
        
        self._preprocess_data()
        # print("all_transactions", self.all_transactions)
        
    def _preprocess_data(self):
        # 列重命名
        self.all_transactions.rename(columns={
            v: k for k, v in self.config["required_columns"].items()
        }, inplace=True)
        
        # 处理时间格式（带时区信息）
        self.all_transactions["trade_time"] = pd.to_datetime(
            self.all_transactions["trade_time"].str[:19]
        )
        
        # 转换金额单位为万元（假设原始单位是元）
        self.all_transactions["nominal_amount"] = self.all_transactions["nominal_amount"] / 10000
        self.all_transactions["settlement_amount"] = self.all_transactions["settlement_amount"] / 10000
        
        # 过滤有效交易类型
        valid_types = ['NDM']  # 根据数据中的trdng_md_cd列值
        self.all_transactions = self.all_transactions[
            self.all_transactions["trade_type"].isin(valid_types)
        ]
        
        if self.config["remove_market_makers"]:
            self.all_transactions = self.all_transactions[
                ~self.all_transactions["seller"].isin(self.market_makers) &
                ~self.all_transactions["buyer"].isin(self.market_makers)
            ]

    def analyze_transaction_chains(self):
        grouped = self.all_transactions.groupby("trade_date")
        for date_str, daily_transactions in grouped:
            print("Analyzing transaction chains", daily_transactions)
            date_folder = Path(self.config["result_folder"]) / date_str
            date_folder.mkdir(exist_ok=True)
            
            bond_groups = daily_transactions.groupby("bond_name")
            # print("Analyzing transaction chains", daily_transactions)
            # for bond_name, bond_transactions in bond_groups:
            #     self._process_bond_transactions(
            #         bond_name, bond_transactions, date_folder
            #     )

    def _process_bond_transactions(self, bond_name, transactions, output_dir):
        """处理单只债券的交易"""
        # 确定价格阈值
        bond_type = transactions["bond_type"].iloc[0]
        price_threshold = (
            self.config["interest_rate_bond_threshold"] 
            if bond_type in ["国债", "政策性金融债"] 
            else self.config["other_bond_threshold"]
        )
        
        # 识别可疑机构
        suspicious_institutions = self._find_suspicious_institutions(transactions)
        if not suspicious_institutions:
            return
        
        # 合并相同交易对手的交易
        consolidated_transactions = self._consolidate_duplicate_trades(transactions)
        
        # 追踪交易链
        results = []
        for institution in suspicious_institutions:
            chain_results = self._trace_institution_chains(
                institution, consolidated_transactions, price_threshold
            )
            results.extend(chain_results)
        
        # 分批保存结果
        if results:
            output_path = output_dir / f"{bond_name}_results.csv"
            pd.DataFrame(results).to_csv(output_path, index=False)

    def _find_suspicious_institutions(self, transactions):
        """识别存在可疑净头寸的机构"""
        # 计算各机构的净交易量和损益
        buyers = transactions.groupby("byr_instn_cn_shrt_nm").agg({
            "nmnl_vol": "sum",  # 券面总额
            "stlmnt_amnt": "sum"  # 结算金额
        })
        sellers = transactions.groupby("slr_instn_cn_shrt_nm").agg({
            "nmnl_vol": "sum",  # 券面总额
            "stlmnt_amnt": "sum"  # 结算金额
        })
        
        net_position = buyers.join(sellers, how="outer", lsuffix="_buy", rsuffix="_sell").fillna(0)
        net_position["net_amount"] = net_position["nmnl_vol_sell"] - net_position["nmnl_vol_buy"]
        net_position["net_profit"] = net_position["stlmnt_amnt_sell"] - net_position["stlmnt_amnt_buy"]
        
        # 筛选可疑机构
        threshold = self.config["profit_threshold"] * 10000  # 转换为元
        suspicious = net_position[
            (abs(net_position["net_profit"]) > threshold) &
            (net_position["net_amount"] != 0)
        ].index.tolist()
        
        return suspicious

    def _consolidate_duplicate_trades(self, transactions):
        """合并相同交易对手的重复交易"""
        group_keys = [
            "slr_instn_cn_shrt_nm",  # 卖方机构
            "byr_instn_cn_shrt_nm",  # 买方机构
            "slr_trdr_nm",  # 卖方交易员
            "byr_trdr_nm",  # 买方交易员
            "yld_to_mrty"  # 到期收益率
        ]
        grouped = transactions.groupby(group_keys)
        
        consolidated = []
        for (seller, buyer, s_trader, b_trader, yld), group in grouped:
            if len(group) > 1:
                combined = pd.Series({
                    "dl_cd": "|".join(group["dl_cd"]),  # 成交编号
                    "nmnl_vol": group["nmnl_vol"].sum(),  # 券面总额
                    "stlmnt_amnt": group["stlmnt_amnt"].sum(),  # 结算金额
                    "net_prc": group["net_prc"].mean(),  # 净价
                    **dict(zip(group_keys, [seller, buyer, s_trader, b_trader, yld]))
                })
                consolidated.append(combined)
            else:
                consolidated.append(group.iloc[0])
        
        return pd.DataFrame(consolidated)

    def _trace_institution_chains(self, institution, transactions, price_threshold):
        """追踪单个机构的交易链条"""
        # 正向追踪（上游）
        upstream_chains = self._trace_transaction_chain(
            institution, transactions, direction="upstream", 
            price_threshold=price_threshold
        )
        
        # 反向追踪（下游）
        downstream_chains = self._trace_transaction_chain(
            institution, transactions, direction="downstream",
            price_threshold=price_threshold
        )
        
        # 合并并分析链条
        combined_chains = self._analyze_combined_chains(
            upstream_chains, downstream_chains, institution
        )
        
        return combined_chains

    def _trace_transaction_chain(self, start_institution, transactions, 
                                direction="upstream", price_threshold=0.1):
        """追踪单个方向的交易链"""
        # 实现核心的链条追踪逻辑（此处需要根据原代码逻辑补充实现细节）
        # 返回追踪到的交易链信息
        return []  # 示例返回

    def _analyze_combined_chains(self, upstream, downstream, institution):
        """分析合并后的交易链条"""
        # 实现链条合并和损益计算逻辑
        return []  # 示例返回
    # 使用示例
if __name__ == "__main__":
    config = {
        "input_files": ["bond_2005496_2006_2402.csv"],
        "result_folder": "analysis_results",
        "profit_threshold": 1000,
        "remove_market_makers": False,
        "market_maker_list": "market_makers.csv"
    }
    
    analyzer = BondTransactionAnalyzer(config)
    analyzer.load_data()
    analyzer.analyze_transaction_chains()
# Out:
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 108         108  CBT20200601301687       NaN  2020-06-01 2020-06-01 14:03:49
# 109         109  CBT20200601301390       NaN  2020-06-01 2020-06-01 13:52:37
# 110         110  CBT20200601303563       NaN  2020-06-01 2020-06-01 15:23:16
# 111         111  CBT20200601302578       NaN  2020-06-01 2020-06-01 14:39:45
# 112         112  CBT20200601301038       NaN  2020-06-01 2020-06-01 13:38:38
# 113         113  CBT20200601302178       NaN  2020-06-01 2020-06-01 14:24:08
# 114         114  CBT20200601301470       NaN  2020-06-01 2020-06-01 13:55:45
# 115         115  CBT20200601302590       NaN  2020-06-01 2020-06-01 14:40:04
# 116         116  CBT20200601302177       NaN  2020-06-01 2020-06-01 14:24:08
# 117         117  CBT20200601302283       NaN  2020-06-01 2020-06-01 14:28:19
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 108  2020-06-01 14:03:49+08:00         NaN          NaN      CBT        NDM
# 109  2020-06-01 13:52:37+08:00         NaN          NaN      CBT        NDM
# 110  2020-06-01 15:23:16+08:00         NaN          NaN      CBT        NDM
# 111  2020-06-01 14:39:45+08:00         NaN          NaN      CBT        NDM
# 112  2020-06-01 13:38:38+08:00         NaN          NaN      CBT        NDM
# 113  2020-06-01 14:24:08+08:00         NaN          NaN      CBT        NDM
# 114  2020-06-01 13:55:45+08:00         NaN          NaN      CBT        NDM
# 115  2020-06-01 14:40:04+08:00         NaN          NaN      CBT        NDM
# 116  2020-06-01 14:24:08+08:00         NaN          NaN      CBT        NDM
# 117  2020-06-01 14:28:19+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 108  ...             NaN           NaN       NaN  2020-06-01 14:03:49+08:00
# 109  ...             NaN           NaN       NaN  2020-06-01 13:52:37+08:00
# 110  ...             NaN           NaN       NaN  2020-06-01 15:23:16+08:00
# 111  ...             NaN           NaN       NaN  2020-06-01 14:39:45+08:00
# 112  ...             NaN           NaN       NaN  2020-06-01 13:38:38+08:00
# 113  ...             NaN           NaN       NaN  2020-06-01 14:24:08+08:00
# 114  ...             NaN           NaN       NaN  2020-06-01 13:55:45+08:00
# 115  ...             NaN           NaN       NaN  2020-06-01 14:40:04+08:00
# 116  ...             NaN           NaN       NaN  2020-06-01 14:24:08+08:00
# 117  ...             NaN           NaN       NaN  2020-06-01 14:28:19+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 108  2020-06-01 14:03:49+08:00         NaN           NaN           NaN
# 109  2020-06-01 13:52:37+08:00         NaN           NaN           NaN
# 110  2020-06-01 15:23:16+08:00         NaN           NaN           NaN
# 111  2020-06-01 14:39:45+08:00         NaN           NaN           NaN
# 112  2020-06-01 13:38:38+08:00         NaN           NaN           NaN
# 113  2020-06-01 14:24:08+08:00         NaN           NaN           NaN
# 114  2020-06-01 13:55:45+08:00         NaN           NaN           NaN
# 115  2020-06-01 14:40:04+08:00         NaN           NaN           NaN
# 116  2020-06-01 14:24:08+08:00         NaN           NaN           NaN
# 117  2020-06-01 14:28:19+08:00         NaN           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 108             NaN          NaN
# 109             NaN          NaN
# 110             NaN          NaN
# 111             NaN          NaN
# 112             NaN          NaN
# 113             NaN          NaN
# 114             NaN          NaN
# 115             NaN          NaN
# 116             NaN          NaN
# 117             NaN          NaN
#
# [10 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 119         119  CBT20200917302756       NaN  2020-09-17 2020-09-17 15:05:56
# 120         120  CBT20200917302255       NaN  2020-09-17 2020-09-17 14:49:02
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 119  2020-09-17 15:05:56+08:00         NaN          NaN      CBT        NDM
# 120  2020-09-17 14:49:02+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 119  ...             NaN           NaN       NaN  2020-09-17 15:05:56+08:00
# 120  ...             NaN           NaN       NaN  2020-09-17 14:49:02+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 119  2020-09-17 15:05:56+08:00         NaN           NaN           NaN
# 120  2020-09-17 14:49:02+08:00         NaN           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 119             NaN          NaN
# 120             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 5           5  CBT20230315308736       NaN  2023-03-15 2023-03-15 17:08:47
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 5  2023-03-15 17:08:47+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 5  ...             NaN           NaN       NaN  2023-03-15 17:08:47+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 5  2023-03-15 17:08:47+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 5             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 1           1  CBT20230316305633       NaN  2023-03-16 2023-03-16 16:11:49
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 1  2023-03-16 16:11:49+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 1  ...             NaN           NaN       NaN  2023-03-16 16:11:49+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 1  2023-03-16 16:11:49+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 1             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 2           2  CBT20230317305102       NaN  2023-03-17 2023-03-17 15:21:05
# 3           3  CBT20230317302290       NaN  2023-03-17 2023-03-17 14:10:33
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 2  2023-03-17 15:21:05+08:00         NaN          NaN      CBT        NDM
# 3  2023-03-17 14:10:33+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 2  ...             NaN           NaN       NaN  2023-03-17 15:21:05+08:00
# 3  ...             NaN           NaN       NaN  2023-03-17 14:10:35+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 2  2023-03-17 15:21:05+08:00         0.0           NaN           NaN
# 3  2023-03-17 14:10:35+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 2             NaN          NaN
# 3             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 4           4  CBT20230329306312       NaN  2023-03-29 2023-03-29 15:55:54
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 4  2023-03-29 15:55:54+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 4  ...             NaN           NaN       NaN  2023-03-29 15:55:55+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 4  2023-03-29 15:55:55+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 4             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 0           0  CBT20230330733544       NaN  2023-03-30 2023-03-30 14:28:07
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 0  2023-03-30 14:28:07+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 0  ...             NaN           NaN       NaN  2023-03-30 14:28:08+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 0  2023-03-30 14:28:08+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 0             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 6           6  CBT20230403303454       NaN  2023-04-03 2023-04-03 14:38:13
# 8           8  CBT20230403304042       NaN  2023-04-03 2023-04-03 14:49:32
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 6  2023-04-03 14:38:13+08:00         NaN          NaN      CBT        NDM
# 8  2023-04-03 14:49:32+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 6  ...             NaN           NaN       NaN  2023-04-03 14:38:14+08:00
# 8  ...             NaN           NaN       NaN  2023-04-03 14:49:34+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 6  2023-04-03 14:38:14+08:00         0.0           NaN           NaN
# 8  2023-04-03 14:49:34+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 6             NaN          NaN
# 8             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains    Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 9           9  CBT20230404302939       NaN  2023-04-04 2023-04-04 14:32:13
#
#                      bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 9  2023-04-04 14:32:13+08:00         NaN          NaN      CBT        NDM
#
#    ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 9  ...             NaN           NaN       NaN  2023-04-04 14:32:13+08:00
#
#                       upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 9  2023-04-04 14:32:13+08:00         0.0           NaN           NaN
#
#    isr_en_full_nm  isr_indstry
# 9             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 11          11  CBT20230406301264       NaN  2023-04-06 2023-04-06 13:45:53
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 11  2023-04-06 13:45:53+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 11  ...             NaN           NaN       NaN  2023-04-06 13:45:54+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 11  2023-04-06 13:45:54+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 11             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 12          12  CBT20230525305995       NaN  2023-05-25 2023-05-25 15:17:34
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 12  2023-05-25 15:17:34+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 12  ...             NaN           NaN       NaN  2023-05-25 15:17:34+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 12  2023-05-25 15:17:34+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 12             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 7            7  CBT20230621300804       NaN  2023-06-21 2023-06-21 10:55:34
# 19          19  CBT20230621300781       NaN  2023-06-21 2023-06-21 10:55:06
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 7   2023-06-21 10:55:34+08:00         NaN          NaN      CBT        NDM
# 19  2023-06-21 10:55:06+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 7   ...             NaN           NaN       NaN  2023-06-21 10:55:34+08:00
# 19  ...             NaN           NaN       NaN  2023-06-21 10:55:06+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 7   2023-06-21 10:55:34+08:00         0.0           NaN           NaN
# 19  2023-06-21 10:55:06+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 7              NaN          NaN
# 19             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 15          15  CBT20230704308129       NaN  2023-07-04 2023-07-04 16:10:54
# 16          16  CBT20230704306299       NaN  2023-07-04 2023-07-04 15:39:00
# 17          17  CBT20230704306309       NaN  2023-07-04 2023-07-04 15:39:11
# 18          18  CBT20230704306282       NaN  2023-07-04 2023-07-04 15:38:44
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 15  2023-07-04 16:10:54+08:00         NaN          NaN      CBT        NDM
# 16  2023-07-04 15:39:00+08:00         NaN          NaN      CBT        NDM
# 17  2023-07-04 15:39:11+08:00         NaN          NaN      CBT        NDM
# 18  2023-07-04 15:38:44+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 15  ...             NaN           NaN       NaN  2023-07-04 16:10:55+08:00
# 16  ...             NaN           NaN       NaN  2023-07-04 15:39:00+08:00
# 17  ...             NaN           NaN       NaN  2023-07-04 15:39:11+08:00
# 18  ...             NaN           NaN       NaN  2023-07-04 15:38:44+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 15  2023-07-04 16:10:55+08:00         0.0           NaN           NaN
# 16  2023-07-04 15:39:00+08:00         0.0           NaN           NaN
# 17  2023-07-04 15:39:11+08:00         0.0           NaN           NaN
# 18  2023-07-04 15:38:44+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 15             NaN          NaN
# 16             NaN          NaN
# 17             NaN          NaN
# 18             NaN          NaN
#
# [4 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 14          14  CBT20230705307694       NaN  2023-07-05 2023-07-05 15:23:07
# 20          20  CBT20230705307661       NaN  2023-07-05 2023-07-05 15:22:42
# 21          21  CBT20230705307683       NaN  2023-07-05 2023-07-05 15:22:55
# 23          23  CBT20230705306152       NaN  2023-07-05 2023-07-05 14:56:10
# 24          24  CBT20230705306153       NaN  2023-07-05 2023-07-05 14:56:10
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 14  2023-07-05 15:23:07+08:00         NaN          NaN      CBT        NDM
# 20  2023-07-05 15:22:42+08:00         NaN          NaN      CBT        NDM
# 21  2023-07-05 15:22:55+08:00         NaN          NaN      CBT        NDM
# 23  2023-07-05 14:56:10+08:00         NaN          NaN      CBT        NDM
# 24  2023-07-05 14:56:10+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 14  ...             NaN           NaN       NaN  2023-07-05 15:23:07+08:00
# 20  ...             NaN           NaN       NaN  2023-07-05 15:22:43+08:00
# 21  ...             NaN           NaN       NaN  2023-07-05 15:22:55+08:00
# 23  ...             NaN           NaN       NaN  2023-07-05 14:56:11+08:00
# 24  ...             NaN           NaN       NaN  2023-07-05 14:56:11+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 14  2023-07-05 15:23:07+08:00         0.0           NaN           NaN
# 20  2023-07-05 15:22:43+08:00         0.0           NaN           NaN
# 21  2023-07-05 15:22:55+08:00         0.0           NaN           NaN
# 23  2023-07-05 14:56:11+08:00         0.0           NaN           NaN
# 24  2023-07-05 14:56:11+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 14             NaN          NaN
# 20             NaN          NaN
# 21             NaN          NaN
# 23             NaN          NaN
# 24             NaN          NaN
#
# [5 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 22          22  CBT20230706301960       NaN  2023-07-06 2023-07-06 13:45:50
# 25          25  CBT20230706301983       NaN  2023-07-06 2023-07-06 13:46:20
# 26          26  CBT20230706304704       NaN  2023-07-06 2023-07-06 14:59:58
# 27          27  CBT20230706304334       NaN  2023-07-06 2023-07-06 14:50:01
# 28          28  CBT20230706304696       NaN  2023-07-06 2023-07-06 14:59:50
# 29          29  CBT20230706304427       NaN  2023-07-06 2023-07-06 14:52:37
# 30          30  CBT20230706301267       NaN  2023-07-06 2023-07-06 13:30:13
# 32          32  CBT20230706301269       NaN  2023-07-06 2023-07-06 13:30:13
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 22  2023-07-06 13:45:50+08:00         NaN          NaN      CBT        NDM
# 25  2023-07-06 13:46:20+08:00         NaN          NaN      CBT        NDM
# 26  2023-07-06 14:59:58+08:00         NaN          NaN      CBT        NDM
# 27  2023-07-06 14:50:01+08:00         NaN          NaN      CBT        NDM
# 28  2023-07-06 14:59:50+08:00         NaN          NaN      CBT        NDM
# 29  2023-07-06 14:52:37+08:00         NaN          NaN      CBT        NDM
# 30  2023-07-06 13:30:13+08:00         NaN          NaN      CBT        NDM
# 32  2023-07-06 13:30:13+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 22  ...             NaN           NaN       NaN  2023-07-06 13:45:50+08:00
# 25  ...             NaN           NaN       NaN  2023-07-06 13:46:20+08:00
# 26  ...             NaN           NaN       NaN  2023-07-06 15:00:00+08:00
# 27  ...             NaN           NaN       NaN  2023-07-06 14:50:01+08:00
# 28  ...             NaN           NaN       NaN  2023-07-06 14:59:51+08:00
# 29  ...             NaN           NaN       NaN  2023-07-06 14:52:38+08:00
# 30  ...             NaN           NaN       NaN  2023-07-06 13:30:16+08:00
# 32  ...             NaN           NaN       NaN  2023-07-06 13:30:17+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 22  2023-07-06 13:45:50+08:00         0.0           NaN           NaN
# 25  2023-07-06 13:46:20+08:00         0.0           NaN           NaN
# 26  2023-07-06 15:00:00+08:00         0.0           NaN           NaN
# 27  2023-07-06 14:50:01+08:00         0.0           NaN           NaN
# 28  2023-07-06 14:59:51+08:00         0.0           NaN           NaN
# 29  2023-07-06 14:52:38+08:00         0.0           NaN           NaN
# 30  2023-07-06 13:30:16+08:00         0.0           NaN           NaN
# 32  2023-07-06 13:30:17+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 22             NaN          NaN
# 25             NaN          NaN
# 26             NaN          NaN
# 27             NaN          NaN
# 28             NaN          NaN
# 29             NaN          NaN
# 30             NaN          NaN
# 32             NaN          NaN
#
# [8 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 31          31  CBT20230707304660       NaN  2023-07-07 2023-07-07 14:59:24
# 33          33  CBT20230707304635       NaN  2023-07-07 2023-07-07 14:59:19
# 34          34  CBT20230707305018       NaN  2023-07-07 2023-07-07 15:07:47
# 35          35  CBT20230707303663       NaN  2023-07-07 2023-07-07 14:37:08
# 36          36  CBT20230707301001       NaN  2023-07-07 2023-07-07 11:40:09
# 37          37  CBT20230707303641       NaN  2023-07-07 2023-07-07 14:36:47
# 38          38  CBT20230707301002       NaN  2023-07-07 2023-07-07 11:40:09
# 39          39  CBT20230707300486       NaN  2023-07-07 2023-07-07 10:47:58
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 31  2023-07-07 14:59:24+08:00         NaN          NaN      CBT        NDM
# 33  2023-07-07 14:59:19+08:00         NaN          NaN      CBT        NDM
# 34  2023-07-07 15:07:47+08:00         NaN          NaN      CBT        NDM
# 35  2023-07-07 14:37:08+08:00         NaN          NaN      CBT        NDM
# 36  2023-07-07 11:40:09+08:00         NaN          NaN      CBT        NDM
# 37  2023-07-07 14:36:47+08:00         NaN          NaN      CBT        NDM
# 38  2023-07-07 11:40:09+08:00         NaN          NaN      CBT        NDM
# 39  2023-07-07 10:47:58+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 31  ...             NaN           NaN       NaN  2023-07-07 14:59:42+08:00
# 33  ...             NaN           NaN       NaN  2023-07-07 14:59:33+08:00
# 34  ...             NaN           NaN       NaN  2023-07-07 15:07:48+08:00
# 35  ...             NaN           NaN       NaN  2023-07-07 14:37:09+08:00
# 36  ...             NaN           NaN       NaN  2023-07-07 11:40:09+08:00
# 37  ...             NaN           NaN       NaN  2023-07-07 14:36:47+08:00
# 38  ...             NaN           NaN       NaN  2023-07-07 11:40:09+08:00
# 39  ...             NaN           NaN       NaN  2023-07-07 10:47:58+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 31  2023-07-07 14:59:42+08:00         0.0           NaN           NaN
# 33  2023-07-07 14:59:33+08:00         0.0           NaN           NaN
# 34  2023-07-07 15:07:48+08:00         0.0           NaN           NaN
# 35  2023-07-07 14:37:09+08:00         0.0           NaN           NaN
# 36  2023-07-07 11:40:09+08:00         0.0           NaN           NaN
# 37  2023-07-07 14:36:47+08:00         0.0           NaN           NaN
# 38  2023-07-07 11:40:09+08:00         0.0           NaN           NaN
# 39  2023-07-07 10:47:58+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 31             NaN          NaN
# 33             NaN          NaN
# 34             NaN          NaN
# 35             NaN          NaN
# 36             NaN          NaN
# 37             NaN          NaN
# 38             NaN          NaN
# 39             NaN          NaN
#
# [8 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 40          40  CBT20230710305019       NaN  2023-07-10 2023-07-10 15:14:39
# 41          41  CBT20230710303341       NaN  2023-07-10 2023-07-10 14:32:04
# 42          42  CBT20230710304402       NaN  2023-07-10 2023-07-10 14:58:55
# 43          43  CBT20230710304579       NaN  2023-07-10 2023-07-10 15:05:14
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 40  2023-07-10 15:14:39+08:00         NaN          NaN      CBT        NDM
# 41  2023-07-10 14:32:04+08:00         NaN          NaN      CBT        NDM
# 42  2023-07-10 14:58:55+08:00         NaN          NaN      CBT        NDM
# 43  2023-07-10 15:05:14+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 40  ...             NaN           NaN       NaN  2023-07-10 15:14:39+08:00
# 41  ...             NaN           NaN       NaN  2023-07-10 14:32:05+08:00
# 42  ...             NaN           NaN       NaN  2023-07-10 14:58:55+08:00
# 43  ...             NaN           NaN       NaN  2023-07-10 15:05:15+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 40  2023-07-10 15:14:39+08:00         0.0           NaN           NaN
# 41  2023-07-10 14:32:05+08:00         0.0           NaN           NaN
# 42  2023-07-10 14:58:55+08:00         0.0           NaN           NaN
# 43  2023-07-10 15:05:15+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 40             NaN          NaN
# 41             NaN          NaN
# 42             NaN          NaN
# 43             NaN          NaN
#
# [4 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 45          45  CBT20230711305401       NaN  2023-07-11 2023-07-11 15:14:38
# 46          46  CBT20230711306688       NaN  2023-07-11 2023-07-11 15:35:05
# 47          47  CBT20230711306689       NaN  2023-07-11 2023-07-11 15:35:06
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 45  2023-07-11 15:14:38+08:00         NaN          NaN      CBT        NDM
# 46  2023-07-11 15:35:05+08:00         NaN          NaN      CBT        NDM
# 47  2023-07-11 15:35:06+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 45  ...             NaN           NaN       NaN  2023-07-11 15:14:39+08:00
# 46  ...             NaN           NaN       NaN  2023-07-11 15:35:07+08:00
# 47  ...             NaN           NaN       NaN  2023-07-11 15:35:07+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 45  2023-07-11 15:14:39+08:00         0.0           NaN           NaN
# 46  2023-07-11 15:35:07+08:00         0.0           NaN           NaN
# 47  2023-07-11 15:35:07+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 45             NaN          NaN
# 46             NaN          NaN
# 47             NaN          NaN
#
# [3 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 10          10  CBT20231106305640       NaN  2023-11-06 2023-11-06 15:00:07
# 13          13  CBT20231106305639       NaN  2023-11-06 2023-11-06 15:00:07
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 10  2023-11-06 15:00:07+08:00         NaN          NaN      CBT        NDM
# 13  2023-11-06 15:00:07+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 10  ...             NaN           NaN       NaN  2023-11-06 15:00:11+08:00
# 13  ...             NaN           NaN       NaN  2023-11-06 15:00:11+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 10  2023-11-06 15:00:11+08:00         0.0           NaN           NaN
# 13  2023-11-06 15:00:11+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 10             NaN          NaN
# 13             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 44          44  CBT20231129304752       NaN  2023-11-29 2023-11-29 14:32:46
# 48          48  CBT20231129303047       NaN  2023-11-29 2023-11-29 13:53:10
# 49          49  CBT20231129304644       NaN  2023-11-29 2023-11-29 14:31:48
# 50          50  CBT20231129306052       NaN  2023-11-29 2023-11-29 14:57:56
# 52          52  CBT20231129302492       NaN  2023-11-29 2023-11-29 13:42:55
# 55          55  CBT20231129301575       NaN  2023-11-29 2023-11-29 13:30:58
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 44  2023-11-29 14:32:46+08:00         NaN          NaN      CBT        NDM
# 48  2023-11-29 13:53:10+08:00         NaN          NaN      CBT        NDM
# 49  2023-11-29 14:31:48+08:00         NaN          NaN      CBT        NDM
# 50  2023-11-29 14:57:56+08:00         NaN          NaN      CBT        NDM
# 52  2023-11-29 13:42:55+08:00         NaN          NaN      CBT        NDM
# 55  2023-11-29 13:30:58+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 44  ...             NaN           NaN       NaN  2023-11-29 14:32:46+08:00
# 48  ...             NaN           NaN       NaN  2023-11-29 13:53:11+08:00
# 49  ...             NaN           NaN       NaN  2023-11-29 14:31:49+08:00
# 50  ...             NaN           NaN       NaN  2023-11-29 14:57:57+08:00
# 52  ...             NaN           NaN       NaN  2023-11-29 13:42:56+08:00
# 55  ...             NaN           NaN       NaN  2023-11-29 13:30:59+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 44  2023-11-29 14:32:46+08:00         0.0           NaN           NaN
# 48  2023-11-29 13:53:11+08:00         0.0           NaN           NaN
# 49  2023-11-29 14:31:49+08:00         0.0           NaN           NaN
# 50  2023-11-29 14:57:57+08:00         0.0           NaN           NaN
# 52  2023-11-29 13:42:56+08:00         0.0           NaN           NaN
# 55  2023-11-29 13:30:59+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 44             NaN          NaN
# 48             NaN          NaN
# 49             NaN          NaN
# 50             NaN          NaN
# 52             NaN          NaN
# 55             NaN          NaN
#
# [6 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 53          53  CBT20231130302278       NaN  2023-11-30 2023-11-30 13:45:12
# 56          56  CBT20231130303524       NaN  2023-11-30 2023-11-30 14:29:01
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 53  2023-11-30 13:45:12+08:00         NaN          NaN      CBT        NDM
# 56  2023-11-30 14:29:01+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 53  ...             NaN           NaN       NaN  2023-11-30 13:45:12+08:00
# 56  ...             NaN           NaN       NaN  2023-11-30 14:29:02+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 53  2023-11-30 13:45:12+08:00         0.0           NaN           NaN
# 56  2023-11-30 14:29:02+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 53             NaN          NaN
# 56             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 57          57  CBT20231204301849       NaN  2023-12-04 2023-12-04 14:04:01
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 57  2023-12-04 14:04:01+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 57  ...             NaN           NaN       NaN  2023-12-04 14:04:02+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 57  2023-12-04 14:04:02+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 57             NaN          NaN
#
# [1 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 51          51  CBT20231206305408       NaN  2023-12-06 2023-12-06 15:15:52
# 54          54  CBT20231206308727       NaN  2023-12-06 2023-12-06 16:44:13
# 58          58  CBT20231206308726       NaN  2023-12-06 2023-12-06 16:44:08
# 59          59  CBT20231206305456       NaN  2023-12-06 2023-12-06 15:16:49
# 61          61  CBT20231206303213       NaN  2023-12-06 2023-12-06 14:22:19
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 51  2023-12-06 15:15:52+08:00         NaN          NaN      CBT        NDM
# 54  2023-12-06 16:44:13+08:00         NaN          NaN      CBT        NDM
# 58  2023-12-06 16:44:08+08:00         NaN          NaN      CBT        NDM
# 59  2023-12-06 15:16:49+08:00         NaN          NaN      CBT        NDM
# 61  2023-12-06 14:22:19+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 51  ...             NaN           NaN       NaN  2023-12-06 15:15:52+08:00
# 54  ...             NaN           NaN       NaN  2023-12-06 16:44:13+08:00
# 58  ...             NaN           NaN       NaN  2023-12-06 16:44:08+08:00
# 59  ...             NaN           NaN       NaN  2023-12-06 15:16:49+08:00
# 61  ...             NaN           NaN       NaN  2023-12-06 14:22:24+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 51  2023-12-06 15:15:52+08:00         0.0           NaN           NaN
# 54  2023-12-06 16:44:13+08:00         0.0           NaN           NaN
# 58  2023-12-06 16:44:08+08:00         0.0           NaN           NaN
# 59  2023-12-06 15:16:49+08:00         0.0           NaN           NaN
# 61  2023-12-06 14:22:24+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 51             NaN          NaN
# 54             NaN          NaN
# 58             NaN          NaN
# 59             NaN          NaN
# 61             NaN          NaN
#
# [5 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 60          60  CBT20231207301117       NaN  2023-12-07 2023-12-07 13:35:23
# 63          63  CBT20231207300970       NaN  2023-12-07 2023-12-07 13:33:23
# 64          64  CBT20231207300652       NaN  2023-12-07 2023-12-07 13:30:11
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 60  2023-12-07 13:35:23+08:00         NaN          NaN      CBT        NDM
# 63  2023-12-07 13:33:23+08:00         NaN          NaN      CBT        NDM
# 64  2023-12-07 13:30:11+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 60  ...             NaN           NaN       NaN  2023-12-07 13:35:23+08:00
# 63  ...             NaN           NaN       NaN  2023-12-07 13:33:23+08:00
# 64  ...             NaN           NaN       NaN  2023-12-07 13:30:12+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 60  2023-12-07 13:35:23+08:00         0.0           NaN           NaN
# 63  2023-12-07 13:33:23+08:00         0.0           NaN           NaN
# 64  2023-12-07 13:30:12+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 60             NaN          NaN
# 63             NaN          NaN
# 64             NaN          NaN
#
# [3 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 62          62  CBT20231211303601       NaN  2023-12-11 2023-12-11 14:19:24
# 65          65  CBT20231211303871       NaN  2023-12-11 2023-12-11 14:24:34
# 66          66  CBT20231211303417       NaN  2023-12-11 2023-12-11 14:14:56
# 67          67  CBT20231211304030       NaN  2023-12-11 2023-12-11 14:27:12
# 68          68  CBT20231211303419       NaN  2023-12-11 2023-12-11 14:14:56
# 69          69  CBT20231211303860       NaN  2023-12-11 2023-12-11 14:24:14
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 62  2023-12-11 14:19:24+08:00         NaN          NaN      CBT        NDM
# 65  2023-12-11 14:24:34+08:00         NaN          NaN      CBT        NDM
# 66  2023-12-11 14:14:56+08:00         NaN          NaN      CBT        NDM
# 67  2023-12-11 14:27:12+08:00         NaN          NaN      CBT        NDM
# 68  2023-12-11 14:14:56+08:00         NaN          NaN      CBT        NDM
# 69  2023-12-11 14:24:14+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 62  ...             NaN           NaN       NaN  2023-12-11 14:19:24+08:00
# 65  ...             NaN           NaN       NaN  2023-12-11 14:24:34+08:00
# 66  ...             NaN           NaN       NaN  2023-12-11 14:14:56+08:00
# 67  ...             NaN           NaN       NaN  2023-12-11 14:27:13+08:00
# 68  ...             NaN           NaN       NaN  2023-12-11 14:14:57+08:00
# 69  ...             NaN           NaN       NaN  2023-12-11 14:24:14+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 62  2023-12-11 14:19:24+08:00         0.0           NaN           NaN
# 65  2023-12-11 14:24:34+08:00         0.0           NaN           NaN
# 66  2023-12-11 14:14:56+08:00         0.0           NaN           NaN
# 67  2023-12-11 14:27:13+08:00         0.0           NaN           NaN
# 68  2023-12-11 14:14:57+08:00         0.0           NaN           NaN
# 69  2023-12-11 14:24:14+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 62             NaN          NaN
# 65             NaN          NaN
# 66             NaN          NaN
# 67             NaN          NaN
# 68             NaN          NaN
# 69             NaN          NaN
#
# [6 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 70          70  CBT20231212303386       NaN  2023-12-12 2023-12-12 14:14:11
# 71          71  CBT20231212303392       NaN  2023-12-12 2023-12-12 14:14:19
# 72          72  CBT20231212303172       NaN  2023-12-12 2023-12-12 14:08:34
# 73          73  CBT20231212303171       NaN  2023-12-12 2023-12-12 14:08:34
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 70  2023-12-12 14:14:11+08:00         NaN          NaN      CBT        NDM
# 71  2023-12-12 14:14:19+08:00         NaN          NaN      CBT        NDM
# 72  2023-12-12 14:08:34+08:00         NaN          NaN      CBT        NDM
# 73  2023-12-12 14:08:34+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 70  ...             NaN           NaN       NaN  2023-12-12 14:14:14+08:00
# 71  ...             NaN           NaN       NaN  2023-12-12 14:14:19+08:00
# 72  ...             NaN           NaN       NaN  2023-12-12 14:08:36+08:00
# 73  ...             NaN           NaN       NaN  2023-12-12 14:08:34+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 70  2023-12-12 14:14:14+08:00         0.0           NaN           NaN
# 71  2023-12-12 14:14:19+08:00         0.0           NaN           NaN
# 72  2023-12-12 14:08:36+08:00         0.0           NaN           NaN
# 73  2023-12-12 14:08:34+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 70             NaN          NaN
# 71             NaN          NaN
# 72             NaN          NaN
# 73             NaN          NaN
#
# [4 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 75          75  CBT20231214311293       NaN  2023-12-14 2023-12-14 16:02:20
# 76          76  CBT20231214312810       NaN  2023-12-14 2023-12-14 16:26:04
# 77          77  CBT20231214305975       NaN  2023-12-14 2023-12-14 14:48:19
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 75  2023-12-14 16:02:20+08:00         NaN          NaN      CBT        NDM
# 76  2023-12-14 16:26:04+08:00         NaN          NaN      CBT        NDM
# 77  2023-12-14 14:48:19+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 75  ...             NaN           NaN       NaN  2023-12-14 16:06:44+08:00
# 76  ...             NaN           NaN       NaN  2023-12-14 16:27:40+08:00
# 77  ...             NaN           NaN       NaN  2023-12-14 14:48:19+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 75  2023-12-14 16:06:44+08:00         0.0           NaN           NaN
# 76  2023-12-14 16:27:40+08:00         0.0           NaN           NaN
# 77  2023-12-14 14:48:19+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 75             NaN          NaN
# 76             NaN          NaN
# 77             NaN          NaN
#
# [3 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 74          74  CBT20231215307209       NaN  2023-12-15 2023-12-15 15:14:10
# 78          78  CBT20231215304829       NaN  2023-12-15 2023-12-15 14:30:28
# 80          80  CBT20231215304839       NaN  2023-12-15 2023-12-15 14:30:42
# 81          81  CBT20231215301316       NaN  2023-12-15 2023-12-15 11:46:41
# 82          82  CBT20231215301317       NaN  2023-12-15 2023-12-15 11:46:42
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 74  2023-12-15 15:14:10+08:00         NaN          NaN      CBT        NDM
# 78  2023-12-15 14:30:28+08:00         NaN          NaN      CBT        NDM
# 80  2023-12-15 14:30:42+08:00         NaN          NaN      CBT        NDM
# 81  2023-12-15 11:46:41+08:00         NaN          NaN      CBT        NDM
# 82  2023-12-15 11:46:42+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 74  ...             NaN           NaN       NaN  2023-12-15 15:14:11+08:00
# 78  ...             NaN           NaN       NaN  2023-12-15 14:30:28+08:00
# 80  ...             NaN           NaN       NaN  2023-12-15 14:30:43+08:00
# 81  ...             NaN           NaN       NaN  2023-12-15 11:46:41+08:00
# 82  ...             NaN           NaN       NaN  2023-12-15 11:46:43+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 74  2023-12-15 15:14:11+08:00         0.0           NaN           NaN
# 78  2023-12-15 14:30:28+08:00         0.0           NaN           NaN
# 80  2023-12-15 14:30:43+08:00         0.0           NaN           NaN
# 81  2023-12-15 11:46:41+08:00         0.0           NaN           NaN
# 82  2023-12-15 11:46:43+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 74             NaN          NaN
# 78             NaN          NaN
# 80             NaN          NaN
# 81             NaN          NaN
# 82             NaN          NaN
#
# [5 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 79          79  CBT20231218308494       NaN  2023-12-18 2023-12-18 15:27:55
# 83          83  CBT20231218308495       NaN  2023-12-18 2023-12-18 15:27:55
# 85          85  CBT20231218311434       NaN  2023-12-18 2023-12-18 16:10:45
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 79  2023-12-18 15:27:55+08:00         NaN          NaN      CBT        NDM
# 83  2023-12-18 15:27:55+08:00         NaN          NaN      CBT        NDM
# 85  2023-12-18 16:10:45+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 79  ...             NaN           NaN       NaN  2023-12-18 15:27:56+08:00
# 83  ...             NaN           NaN       NaN  2023-12-18 15:27:56+08:00
# 85  ...             NaN           NaN       NaN  2023-12-18 16:10:47+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 79  2023-12-18 15:27:56+08:00         0.0           NaN           NaN
# 83  2023-12-18 15:27:56+08:00         0.0           NaN           NaN
# 85  2023-12-18 16:10:47+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 79             NaN          NaN
# 83             NaN          NaN
# 85             NaN          NaN
#
# [3 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 94           94  CBT20231220310761       NaN  2023-12-20 2023-12-20 16:33:09
# 118         118  CBT20231220310762       NaN  2023-12-20 2023-12-20 16:33:09
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 94   2023-12-20 16:33:09+08:00         NaN          NaN      CBT        NDM
# 118  2023-12-20 16:33:09+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 94   ...             NaN           NaN       NaN  2023-12-20 16:33:10+08:00
# 118  ...             NaN           NaN       NaN  2023-12-20 16:33:10+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 94   2023-12-20 16:33:10+08:00         0.0           NaN           NaN
# 118  2023-12-20 16:33:10+08:00         0.0           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 94              NaN          NaN
# 118             NaN          NaN
#
# [2 rows x 147 columns]
# Analyzing transaction chains     Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 86          86  CBT20231221310994       NaN  2023-12-21 2023-12-21 16:59:49
# 87          87  CBT20231221304841       NaN  2023-12-21 2023-12-21 14:55:25
# 88          88  CBT20231221303405       NaN  2023-12-21 2023-12-21 14:20:49
# 95          95  CBT20231221304829       NaN  2023-12-21 2023-12-21 14:55:09
# 96          96  CBT20231221303401       NaN  2023-12-21 2023-12-21 14:20:44
# 97          97  CBT20231221306564       NaN  2023-12-21 2023-12-21 15:29:26
#
#                       bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 86  2023-12-21 16:59:49+08:00         NaN          NaN      CBT        NDM
# 87  2023-12-21 14:55:25+08:00         NaN          NaN      CBT        NDM
# 88  2023-12-21 14:20:49+08:00         NaN          NaN      CBT        NDM
# 95  2023-12-21 14:55:09+08:00         NaN          NaN      CBT        NDM
# 96  2023-12-21 14:20:44+08:00         NaN          NaN      CBT        NDM
# 97  2023-12-21 15:29:26+08:00         NaN          NaN      CBT        NDM
#
#     ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 86  ...             NaN           NaN       NaN  2023-12-21 16:59:49+08:00
# 87  ...             NaN           NaN       NaN  2023-12-21 14:55:25+08:00
# 88  ...             NaN           NaN       NaN  2023-12-21 14:20:49+08:00
# 95  ...             NaN           NaN       NaN  2023-12-21 14:55:10+08:00
# 96  ...             NaN           NaN       NaN  2023-12-21 14:20:45+08:00
# 97  ...             NaN           NaN       NaN  2023-12-21 15:29:26+08:00
#
#                        upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 86  2023-12-21 16:59:49+08:00         0.0           NaN           NaN
# 87  2023-12-21 14:55:25+08:00         0.0           NaN           NaN
# 88  2023-12-21 14:20:49+08:00         0.0           NaN           NaN
# 95  2023-12-21 14:55:10+08:00         0.0           NaN           NaN
# 96  2023-12-21 14:20:45+08:00         0.0           NaN           NaN
# 97  2023-12-21 15:29:26+08:00         0.0           NaN           NaN
#
#     isr_en_full_nm  isr_indstry
# 86             NaN          NaN
# 87             NaN          NaN
# 88             NaN          NaN
# 95             NaN          NaN
# 96             NaN          NaN
# 97             NaN          NaN
#
# [6 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 89           89  CBT20231222302491       NaN  2023-12-22 2023-12-22 13:35:42
# 90           90  CBT20231222303973       NaN  2023-12-22 2023-12-22 14:05:57
# 91           91  CBT20231222303495       NaN  2023-12-22 2023-12-22 13:54:34
# 92           92  CBT20231222303494       NaN  2023-12-22 2023-12-22 13:54:34
# 93           93  CBT20231222300881       NaN  2023-12-22 2023-12-22 10:59:08
# 98           98  CBT20231222303993       NaN  2023-12-22 2023-12-22 14:06:05
# 99           99  CBT20231222302442       NaN  2023-12-22 2023-12-22 13:35:28
# 100         100  CBT20231222300877       NaN  2023-12-22 2023-12-22 10:59:04
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 89   2023-12-22 13:35:42+08:00         NaN          NaN      CBT        NDM
# 90   2023-12-22 14:05:57+08:00         NaN          NaN      CBT        NDM
# 91   2023-12-22 13:54:34+08:00         NaN          NaN      CBT        NDM
# 92   2023-12-22 13:54:34+08:00         NaN          NaN      CBT        NDM
# 93   2023-12-22 10:59:08+08:00         NaN          NaN      CBT        NDM
# 98   2023-12-22 14:06:05+08:00         NaN          NaN      CBT        NDM
# 99   2023-12-22 13:35:28+08:00         NaN          NaN      CBT        NDM
# 100  2023-12-22 10:59:04+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 89   ...             NaN           NaN       NaN  2023-12-22 13:35:43+08:00
# 90   ...             NaN           NaN       NaN  2023-12-22 14:05:59+08:00
# 91   ...             NaN           NaN       NaN  2023-12-22 13:54:35+08:00
# 92   ...             NaN           NaN       NaN  2023-12-22 13:54:34+08:00
# 93   ...             NaN           NaN       NaN  2023-12-22 10:59:08+08:00
# 98   ...             NaN           NaN       NaN  2023-12-22 14:06:10+08:00
# 99   ...             NaN           NaN       NaN  2023-12-22 13:35:30+08:00
# 100  ...             NaN           NaN       NaN  2023-12-22 10:59:05+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 89   2023-12-22 13:35:43+08:00         0.0           NaN           NaN
# 90   2023-12-22 14:05:59+08:00         0.0           NaN           NaN
# 91   2023-12-22 13:54:35+08:00         0.0           NaN           NaN
# 92   2023-12-22 13:54:34+08:00         0.0           NaN           NaN
# 93   2023-12-22 10:59:08+08:00         0.0           NaN           NaN
# 98   2023-12-22 14:06:10+08:00         0.0           NaN           NaN
# 99   2023-12-22 13:35:30+08:00         0.0           NaN           NaN
# 100  2023-12-22 10:59:05+08:00         0.0           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 89              NaN          NaN
# 90              NaN          NaN
# 91              NaN          NaN
# 92              NaN          NaN
# 93              NaN          NaN
# 98              NaN          NaN
# 99              NaN          NaN
# 100             NaN          NaN
#
# [8 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 84           84  CBT20231225307892       NaN  2023-12-25 2023-12-25 15:25:11
# 101         101  CBT20231225306493       NaN  2023-12-25 2023-12-25 15:02:11
# 102         102  CBT20231225306489       NaN  2023-12-25 2023-12-25 15:02:07
# 104         104  CBT20231225304992       NaN  2023-12-25 2023-12-25 14:35:57
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 84   2023-12-25 15:25:11+08:00         NaN          NaN      CBT        NDM
# 101  2023-12-25 15:02:11+08:00         NaN          NaN      CBT        NDM
# 102  2023-12-25 15:02:07+08:00         NaN          NaN      CBT        NDM
# 104  2023-12-25 14:35:57+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 84   ...             NaN           NaN       NaN  2023-12-25 15:25:12+08:00
# 101  ...             NaN           NaN       NaN  2023-12-25 15:02:12+08:00
# 102  ...             NaN           NaN       NaN  2023-12-25 15:02:08+08:00
# 104  ...             NaN           NaN       NaN  2023-12-25 14:35:58+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 84   2023-12-25 15:25:12+08:00         0.0           NaN           NaN
# 101  2023-12-25 15:02:12+08:00         0.0           NaN           NaN
# 102  2023-12-25 15:02:08+08:00         0.0           NaN           NaN
# 104  2023-12-25 14:35:58+08:00         0.0           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 84              NaN          NaN
# 101             NaN          NaN
# 102             NaN          NaN
# 104             NaN          NaN
#
# [4 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 105         105  CBT20231226305573       NaN  2023-12-26 2023-12-26 14:45:55
# 106         106  CBT20231226305605       NaN  2023-12-26 2023-12-26 14:46:25
# 107         107  CBT20231226305629       NaN  2023-12-26 2023-12-26 14:46:49
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 105  2023-12-26 14:45:55+08:00         NaN          NaN      CBT        NDM
# 106  2023-12-26 14:46:25+08:00         NaN          NaN      CBT        NDM
# 107  2023-12-26 14:46:49+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 105  ...             NaN           NaN       NaN  2023-12-26 14:45:55+08:00
# 106  ...             NaN           NaN       NaN  2023-12-26 14:46:26+08:00
# 107  ...             NaN           NaN       NaN  2023-12-26 14:46:49+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 105  2023-12-26 14:45:55+08:00         0.0           NaN           NaN
# 106  2023-12-26 14:46:26+08:00         0.0           NaN           NaN
# 107  2023-12-26 14:46:49+08:00         0.0           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 105             NaN          NaN
# 106             NaN          NaN
# 107             NaN          NaN
#
# [3 rows x 147 columns]
# Analyzing transaction chains      Unnamed: 0           trade_id  dt_cnfrm  trade_date          trade_time  \
# 103         103  CBT20240125308730       NaN  2024-01-25 2024-01-25 15:00:33
#
#                        bsns_tm  qt_rqst_cd  trd_rcrd_cd prdct_cd trade_type  \
# 103  2024-01-25 15:00:33+08:00         NaN          NaN      CBT        NDM
#
#      ... trd_instrctn_cd  btch_list_cd  dl_sr_no                     crt_tm  \
# 103  ...             NaN           NaN       NaN  2024-01-25 15:00:34+08:00
#
#                         upd_tm  pips_trd_f  bond_isin_cd  cmu_issue_no  \
# 103  2024-01-25 15:00:34+08:00         0.0           NaN           NaN
#
#      isr_en_full_nm  isr_indstry
# 103             NaN          NaN
#
# [1 rows x 147 columns]
